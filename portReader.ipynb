# %%
import serial
import time
import subprocess


ser = serial.Serial('/dev/tty.usbmodem14201',9600)
line = 0


def main():
    while 1:
        listen()

def show_image1():
    print('show image 1')
    #subprocess.call('bash display_image.sh haveanawesomeday.jpg', shell=True)

def listen():
    
    global line,ser
    
    if(ser.in_waiting > 0):
        serInput = ser.readline().decode('UTF-8')
        
        h = serInput.split(' ')[0]
        f = serInput.split(' ')[1]
        
        print(h)
        
        if float(h) > 90:
            print('balmy')
            
        ser.reset_input_buffer()

main()
# Out:
# 37.20
# 37.20
# 37.20
# 37.20
# 37.20
# 37.20
# 60.50
# 60.50
# 83.60
# 83.60
# 88.80
# 88.80
# 92.60
# balmy
# 92.60
# balmy
# 94.70
# balmy
# 94.70
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 99.90
# balmy
# 95.20
# balmy
# 95.20
# balmy
# 89.70
# 89.70
# 79.20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1b54414fe161> in <module>
#      33         ser.reset_input_buffer()
#      34
# ---> 35 main()
#
# <ipython-input-1-1b54414fe161> in main()
#      10 def main():
#      11     while 1:
# ---> 12         listen()
#      13
#      14 def show_image1():
#
# <ipython-input-1-1b54414fe161> in listen()
#      20     global line,ser
#      21
# ---> 22     if(ser.in_waiting > 0):
#      23         serInput = ser.readline().decode('UTF-8')
#      24
#
# /anaconda3/lib/python3.7/site-packages/serial/serialposix.py in in_waiting(self)
#     465         """Return the number of bytes currently in the input buffer."""
#     466         #~ s = fcntl.ioctl(self.fd, termios.FIONREAD, TIOCM_zero_str)
# --> 467         s = fcntl.ioctl(self.fd, TIOCINQ, TIOCM_zero_str)
#     468         return struct.unpack('I', s)[0]
#     469
#
# KeyboardInterrupt:
